# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Emojipedia

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import time, sleep
from IPython.display import clear_output
from random import randint

# %%
base_url = "https://emojipedia.org"

# %%
categories = ["people", "nature", "food-drink", "activity", "travel-places", "objects", "symbols", "flags"]

# %%
# Return parsed web page
def parsed_page(url):
    response = requests.get(url)
    
    # Send a warning if Response code isn't 200
    #if response.status_code != 200:
    #    warn(f'Request for url : {url} has code: {response.status_code}')
    content = response.content
    parser = BeautifulSoup(content, 'html.parser')
    return parser

# %%
parser = parsed_page("https://emojipedia.org/grinning-face-with-big-eyes/")

# %%
base_code_url = "https://emojipedia.org/emoji/" # url with specific code description

# Function scaping needed information on 1 page
def one_page_scraping(url, base_code_url):    
    parser = parsed_page(url)
    # Get the symbol
    emoji_symbol = parser.select("h1 .emoji")[0].text
    # Get only the name
    emoji_name = parser.find("h1").text[1:].strip()
    # Get the description (without the last paragraph saying when the emoji was added to the library)
    emoji_description = ""
    emoji_descr_list = parser.select(".description p")
    for paragraph in emoji_descr_list[:-1]: # Selection all but the last paragraph
        #print(paragraph.text)
        emoji_description += paragraph.get_text(strip=True).replace('\xa0','')
    
    # Get the emoji_code
    parser_code = parsed_page(base_code_url + emoji_symbol)
    emoji_code_list = parser_code.select(".emoji-detail td")
    if len(emoji_code_list)<3:
        emoji_code = ""
    else:
        emoji_code = emoji_code_list[3].text
    
    
    emoji_attr = {"emoji_symbol": emoji_symbol, "emoji_name": emoji_name, "emoji_code":emoji_code, 
                   "emoji_description":emoji_description }

    return emoji_attr

# %%
# We'll control the rate at which our requests are sent to avoid our IP address to be banned
start_time = time()
request_num = 0

# Exploring the different categories
list_emoji_attr = [] # we'll use it to add keep the different dictionnaries for each emoji
for cat in categories:
    print("We are scraping the emojis of category : ", cat)
    clear_output(wait=True)
    
    cat_url = base_url + "/" + cat
    # get the page
    parser = parsed_page(cat_url)
   
    # Get the list of url's of individual emoji pages for current category
    href_list = parser.select(".emoji-list a")
    
    # Going through all emojis of current categorie
    for href in href_list:  
        request_num += 1 # Updating resquests counter
        
        emoji_url = href.get('href')
        emoji_full_url = base_url + emoji_url
        emoji_attr = one_page_scraping(emoji_full_url, base_code_url)
        
        # Every 20 requests do a break of a few seconds
        if request_num%20 == 0:
            sleep(randint(3,15))
            elapsed_time = time() - start_time
            print(f'Request: {request_num}; Frequency: {request_num/elapsed_time}')
            clear_output(wait=True)
            
        list_emoji_attr.append(emoji_attr)
        
# Converting list of dictionaries to a pandas DataFrame
emoji_pedia_df = pd.DataFrame(list_emoji_attr)
# Out:
# Request: 1760; Frequency: 0.594117586235585

# %%
print(emoji_pedia_df.shape)
emoji_pedia_df.sample(50)
# Out:
# (1764, 4)
#      emoji_symbol                     emoji_name  \
# 1513           🇦🇸         🇸 Flag: American Samoa
# 939             🚜                        Tractor
# 1410          0️⃣           ️⃣ Keycap Digit Zero
# 1670           🇳🇫         🇫 Flag: Norfolk Island
# 668             🥨                        Pretzel
# 865            🏕️                      ️ Camping
# 461             🐺                           Wolf
# 83              😩                     Weary Face
# 1550           🇨🇳                  🇳 Flag: China
# 406             🥼                       Lab Coat
# 951             🚥       Horizontal Traffic Light
# 345             💃                  Woman Dancing
# 1222            🤍                    White Heart
# 803            🎟️            ️ Admission Tickets
# 443             💼                      Briefcase
# 1338            ♌                            Leo
# 799             🎪                    Circus Tent
# 906             🌆              Cityscape at Dusk
# 729             🥛                  Glass of Milk
# 391         👩‍👧‍👦  ‍👧‍👦 Family: Woman, Girl, Boy
# 394             👤             Bust in Silhouette
# 1634           🇱🇧                🇧 Flag: Lebanon
# 1233            💈                    Barber Pole
# 1336            ♊                         Gemini
# 1239            🕑                    Two O’Clock
# 532             🐲                    Dragon Face
# 1674           🇳🇴                 🇴 Flag: Norway
# 626            ☄️                        ️ Comet
# 836             🥌                  Curling Stone
# 1751           🇻🇺                🇺 Flag: Vanuatu
# 1407           ™️                   ️ Trade Mark
# 113             🤚            Raised Back of Hand
# 1554           🇨🇺                   🇺 Flag: Cuba
# 46              😷         Face with Medical Mask
# 410             👖                          Jeans
# 483             🐏                            Ram
# 1635           🇱🇨              🇨 Flag: St. Lucia
# 764          🚣‍♂️            ‍♂️ Man Rowing Boat
# 49              🤢                 Nauseated Face
# 1268            🔈             Speaker Low Volume
# 383           👨‍👦            ‍👦 Family: Man, Boy
# 354             🧘       Person in Lotus Position
# 28              🤭      Face with Hand Over Mouth
# 357             👫    Woman and Man Holding Hands
# 1050            🔋                        Battery
# 656            🌶️                   ️ Hot Pepper
# 1055           ⌨️                     ️ Keyboard
# 1745           🇻🇦           🇦 Flag: Vatican City
# 866            🏖️          ️ Beach with Umbrella
# 623            ❄️                    ️ Snowflake
#
#                                      emoji_code  \
# 1513                           U+1F1E6, U+1F1F8
# 939                                     U+1F69C
# 1410                       U+30, U+FE0F, U+20E3
# 1670                           U+1F1F3, U+1F1EB
# 668                                     U+1F968
# 865                             U+1F3D5, U+FE0F
# 461                                     U+1F43A
# 83                                      U+1F629
# 1550                           U+1F1E8, U+1F1F3
# 406                                     U+1F97C
# 951                                     U+1F6A5
# 345                                     U+1F483
# 1222                                    U+1F90D
# 803                             U+1F39F, U+FE0F
# 443                                     U+1F4BC
# 1338                                     U+264C
# 799                                     U+1F3AA
# 906                                     U+1F306
# 729                                     U+1F95B
# 391   U+1F469, U+200D, U+1F467, U+200D, U+1F466
# 394                                     U+1F464
# 1634                           U+1F1F1, U+1F1E7
# 1233                                    U+1F488
# 1336                                     U+264A
# 1239                                    U+1F551
# 532                                     U+1F432
# 1674                           U+1F1F3, U+1F1F4
# 626                              U+2604, U+FE0F
# 836                                     U+1F94C
# 1751                           U+1F1FB, U+1F1FA
# 1407                             U+2122, U+FE0F
# 113                                     U+1F91A
# 1554                           U+1F1E8, U+1F1FA
# 46                                      U+1F637
# 410                                     U+1F456
# 483                                     U+1F40F
# 1635                           U+1F1F1, U+1F1E8
# 764             U+1F6A3, U+200D, U+2642, U+FE0F
# 49                                      U+1F922
# 1268                                    U+1F508
# 383                    U+1F468, U+200D, U+1F466
# 354                                     U+1F9D8
# 28                                      U+1F92D
# 357                                     U+1F46B
# 1050                                    U+1F50B
# 656                             U+1F336, U+FE0F
# 1055                             U+2328, U+FE0F
# 1745                           U+1F1FB, U+1F1E6
# 866                             U+1F3D6, U+FE0F
# 623                              U+2744, U+FE0F
#
#                                       emoji_description
# 1513  The flag for American Samoa, which may show as...
# 939   A tractor, may be used by a farmer or other oc...
# 1410  The Keycap Digit Zero emoji is akeycap sequenc...
# 1670  The flag forNorfolk Island, which may show as ...
# 668   The heart-shaped twist of a hard or soft golde...
# 865   A campsite featuring atentand atree, and perha...
# 461   The face of a wolf, a howling canine that hunt...
# 83    A yellow face with closed eyes, furrowed brows...
# 1550  The flag forChina, which may show as the lette...
# 406          A white coat worn in a science laboratory.
# 951   A set of red, orange (amber) and green traffic...
# 345   A person dancing, mostcommonly displayed aswom...
# 1222  A white heart emoji to accompany other hearts ...
# 803   A ticket or tickets to an event that may say "...
# 443   A place to store notes and other office materi...
# 1338  TheLeo astrological sign in the Zodiac. This Z...
# 799   A circular ‘big top’ circus tent, with atriang...
# 906   A view of city buildings as the last light dis...
# 729   A tall glass of white milk, as from acowbut al...
# 391   The Family: Woman, Girl, Boy emoji is aZWJ seq...
# 394   Generic profile of one person. Often used in i...
# 1634  The flag forLebanon, which may show as the let...
# 1233  A pole spiraled with red, white, and blue stri...
# 1336  TheGemini astrological sign in the Zodiac. Thi...
# 1239
# 532   The face of adragon, a mythical creature resem...
# 1674  The flag forNorway, which may show as the lett...
# 626   Acomet, an icy, rocky space object that can fo...
# 836
# 1751  The flag forVanuatu, which may show as the let...
# 1407  A trademark symbol, the lettersTMdisplayedafte...
# 113   Araised hand, showing the reverse side of the ...
# 1554  The flag for Cuba, which may show as the lette...
# 46    A yellow face with closed eyes wearing a white...
# 410   Denim jeans, worn by menor women. A popular fo...
# 483   A ram, a male sheep with large, spiraling horn...
# 1635  The Flag: St. Lucia emoji is aflag sequencecom...
# 764   The male version of the🚣Rowboatemoji. Currentl...
# 49    A sickly-green face with concerned eyes and pu...
# 1268   A speaker cone displayed without any soundwaves.
# 383   The Family: Man, Boy emoji is aZWJ sequencecom...
# 354   Person in Lotus Positionwas approved as part o...
# 28    A yellow face with a hand covering its mouth. ...
# 357   A woman and manholding hands, most likely due ...
# 1050  An electric battery, as used to power such dev...
# 656   A bright redMexicanchili pepper, slightly curl...
# 1055  A keyboard, as used to type on acomputer. Gene...
# 1745  The flag forVatican City, which may show as th...
# 866   A beach showing sand, and an umbrella for prot...
# 623   The unique, feathery ice crystal of a snowflak...

# %%
emoji_pedia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1764 entries, 0 to 1763
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   emoji_symbol       1764 non-null   object
#  1   emoji_name         1764 non-null   object
#  2   emoji_code         1764 non-null   object
#  3   emoji_description  1764 non-null   object
# dtypes: object(4)
# memory usage: 55.2+ KB

# %%
emoji_pedia_df.sample(5)
# Out:
#      emoji_symbol                emoji_name      emoji_code  \
# 1274            🔔                      Bell         U+1F514
# 1291            🚫                Prohibited         U+1F6AB
# 440            ⛑️  ️ Rescue Worker’s Helmet  U+26D1, U+FE0F
# 184             👴                   Old Man         U+1F474
# 933             🚖             Oncoming Taxi         U+1F696
#
#                                       emoji_description
# 1274  A gold or yellow bell, which iscommonly used o...
# 1291  A red circle with a diagonal line through the ...
# 440   A construction helmet, which is worn by thecon...
# 184   An elderly man gray(grey) hair, and visible wr...
# 933   A yellow taxicab,iconically seen inNew York Ci...

# %% [markdown]
#  ### Looking at where some data is missing

# %%
# The cleaning will be done on a copy of the original df
emoji_df = emoji_pedia_df.copy()

# %% [markdown]
# #### 1. Emoji_code

# %%
# Assess
emoji_df[emoji_df["emoji_code"]==""]
# Out:
#      emoji_symbol             emoji_name emoji_code  \
# 1408          #️⃣  ️⃣ Keycap Number Sign
#
#                                       emoji_description
# 1408  A hash key,sometimes referred to as a pound ke...

# %% [markdown]
# Looking on emojipedia the symbol found for this emoji = U+23, U+FE0F

# %%
# Code
emoji_df.iloc[1408,2] = 'U+23, U+FE0F'

# %%
# Test
emoji_df[emoji_df["emoji_symbol"]==""]
# Out:
# Empty DataFrame
# Columns: [emoji_symbol, emoji_name, emoji_code, emoji_description]
# Index: []

# %% [markdown]
# #### 2. emoji_description

# %%
# Assess
emoji_df[emoji_pedia_df['emoji_description']==""]
# Out:
#      emoji_symbol                 emoji_name emoji_code emoji_description
# 153             🧠                      Brain    U+1F9E0
# 154             🦷                      Tooth    U+1F9B7
# 411             🧣                      Scarf    U+1F9E3
# 412             🧤                     Gloves    U+1F9E4
# 414             🧦                      Socks    U+1F9E6
# ...           ...                        ...        ...               ...
# 1487            🔹         Small Blue Diamond    U+1F539
# 1488            🔺    Red Triangle Pointed Up    U+1F53A
# 1489            🔻  Red Triangle Pointed Down    U+1F53B
# 1493            🔲        Black Square Button    U+1F532
# 1497            🏴                 Black Flag    U+1F3F4
#
# [103 rows x 4 columns]

# %% [markdown]
# > Looking a random set of those emojis on Emojipedia, it seems that they don't have a description.
# We'll take there name as description.

# %%
# Code 
emoji_df['emoji_description'] = emoji_df.apply(lambda row: row.emoji_name if row.emoji_description==""
                                               else row.emoji_description, axis=1)

# %%
# Test
print(emoji_df[emoji_df.emoji_description==""])
emoji_df.sample(20)
# Out:
# Empty DataFrame
# Columns: [emoji_symbol, emoji_name, emoji_code, emoji_description]
# Index: []
#      emoji_symbol                      emoji_name  \
# 684             🥙               Stuffed Flatbread
# 1037            💎                       Gem Stone
# 1202            🗿                            Moai
# 1020            🎏                   Carp Streamer
# 1238            🕜                      One-Thirty
# 565             🌼                         Blossom
# 184             👴                         Old Man
# 1098            💶                   Euro Banknote
# 1002            🦼            Motorized Wheelchair
# 11              😊  Smiling Face with Smiling Eyes
# 313          🧞‍♂️                   ‍♂️ Man Genie
# 1704           🇸🇪                  🇪 Flag: Sweden
# 399            ☂️                      ️ Umbrella
# 470             🐴                      Horse Face
# 728             🍼                     Baby Bottle
# 992             💣                            Bomb
# 496             🐹                         Hamster
# 915             🚅                    Bullet Train
# 1719           🇸🇾                   🇾 Flag: Syria
# 288             👼                      Baby Angel
#
#                            emoji_code  \
# 684                           U+1F959
# 1037                          U+1F48E
# 1202                          U+1F5FF
# 1020                          U+1F38F
# 1238                          U+1F55C
# 565                           U+1F33C
# 184                           U+1F474
# 1098                          U+1F4B6
# 1002                          U+1F9BC
# 11                            U+1F60A
# 313   U+1F9DE, U+200D, U+2642, U+FE0F
# 1704                 U+1F1F8, U+1F1EA
# 399                    U+2602, U+FE0F
# 470                           U+1F434
# 728                           U+1F37C
# 992                           U+1F4A3
# 496                           U+1F439
# 915                           U+1F685
# 1719                 U+1F1F8, U+1F1FE
# 288                           U+1F47C
#
#                                       emoji_description
# 684   A flatbread, like pita, stuffed withlettuce,to...
# 1037  A jewel or gem, as set into aring. Depicted in...
# 1202  Amoai, one of the famed, giant stone statues o...
# 1020  Japanesekoinobori, decorative, carp-shaped win...
# 1238                                         One-Thirty
# 565   A flower that has blossomed. Depicted as a flo...
# 184   An elderly man gray(grey) hair, and visible wr...
# 1098  A banded stack of euro banknotes, the paper cu...
# 1002  A wheelchair with amotor. Distinct from♿ Wheel...
# 11    A yellow face with smiling eyes and a broad, c...
# 313   The Man Genie emoji is aZWJ sequencecombining🧞...
# 1704  The flag forSweden, which may show as the lett...
# 399   An opened, dry umbrella. Generally depicted wi...
# 470   The face of a horse, generally facing left. De...
# 728   A bottle ofmilkorformula,as or fed to ababy, w...
# 992   A cartoon-styled bomb, depicted as a black bal...
# 496   A friendly, cartoon-styled face of a hamster—a...
# 915   A high speed train, designed to cover long dis...
# 1719  The flag forSyria, which may show as the lette...
# 288   An angelic baby with wings, and a halo above i...

# %%
# Saving the dataframe as a csv file
emoji_df.to_csv("emojipedia_df_02.csv")
